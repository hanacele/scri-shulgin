# %%
pip install PIL
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.9.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /Users/ctang3/anaconda3/envs/ayahuasca/lib/python3.11/site-packages (from rdkit) (1.25.2)
# Requirement already satisfied: Pillow in /Users/ctang3/anaconda3/envs/ayahuasca/lib/python3.11/site-packages (from rdkit) (10.0.1)
# Downloading rdkit-2023.9.1-cp311-cp311-macosx_11_0_arm64.whl (23.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.9/23.9 MB 3.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
smiles_list
# Out:
# ['SMILES_1', 'SMILES_2', 'SMILES_3']

# %%
import os
import csv
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D

# Function to convert SMILES to SVG image without hydrogen atoms
def smiles_to_svg(smiles, output_folder):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        mol = Chem.AddHs(mol) 
        AllChem.Compute2DCoords(mol) 
        mol = Chem.RemoveHs(mol) 
    
        drawer = rdMolDraw2D.MolDraw2DSVG(300, 300)
        rdDepictor.Compute2DCoords(mol)
        drawer.DrawMolecule(mol)
        drawer.FinishDrawing()

        svg = drawer.GetDrawingText()
        output_file = os.path.join(output_folder, f"{smiles}.svg")
        
        with open(output_file, 'w') as svg_file:
            svg_file.write(svg)
        return True
    else:
        print(f"Failed to convert SMILES: {smiles}")
        return False

# converts csv CIDs into svgs and inputs them into output folder
def convert_csv_to_svgs(input_csv, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    with open(input_csv, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        for row in reader:
            smiles = row[0].strip()
            success = smiles_to_svg(smiles, output_folder)
            if success:
                print(f"Converted: {smiles}")
            else:
                print(f"Failed to convert: {smiles}")


# Specify input CSV file and output folder
input_csv = '/Users/hannah/Desktop/smiles1.csv'
output_folder = '/Users/hannah/Desktop/output_folder'

# Call the function to convert CSV to SVG images and put in output folder
convert_csv_to_svgs(input_csv, output_folder)
# Out:
# Converted: COC1=CC(=CC(=C1OCC=C)OC)CCN
# Converted: CC(CC1=CC(=C(C=C1OC)SC)OC)N
# Converted: CCSC1=C(C=C(C(=C1)OC)CC(C)N)OC
# Converted: CC(C)SC1=C(C=C(C(=C1)OC)CC(C)N)OC
# Converted: CC(CC1=CC(=C(C=C1OC)SC2=CC=CC=C2)OC)N
# Converted: CCCSC1=C(C=C(C(=C1)OC)CC(C)N)OC
# Converted: CCC(CC1=C(C=C(C(=C1)OC)C)OC)N
# Converted: CCOC1=CC(=CC(=C1OCC)OC)CCN
# Converted: CCCCOC1=C(C=C(C=C1OC)CCN)OC
# Converted: CC1=CC(=C(C=C1OC)CC(C)NC)OC
# Converted: CC1=CC(=C(C=C1SC)CC(C)N)SC
# Converted: COC1=CC(=C(C=C1C(CN)OC)OC)Br
# Converted: CC1=CC(=C(C=C1OC)C(CN)OC)OC
# Converted: COC(CN)C1=CC2=C(C=C1)OCO2
# Converted: CC1=CC(=C(C=C1OC)C(CN)O)OC
# Converted: COC1=CC(=CC(=C1OC)OC)C(CN)OC
# Converted: CC(CC1=CC(=C(C(=C1)OC)Br)OC)N
# Converted: CC(CC1=CC2=C(C=C1Br)OCO2)N
# Converted: COC1=CC(=C(C=C1CCN)OC)Br
# Converted: CC(CC1=CC(=C(C(=C1)OC)OCC2=CC=CC=C2)OC)N
# Converted: COC1=CC(=C(C=C1CCN)OC)Cl
# Converted: CC1=CC(=C(C=C1OC)CCN)OC
# Converted: CCC1=CC(=C(C=C1OC)CCN)OC
# Converted: CCOC1=C(C=C(C=C1OC)CC(C)N)OC
# Converted: COC1=CC(=C(C=C1CCN)OC)F
# Converted: CC1=C(C=C(C(=C1C)OC)CCN)OC
# Converted: COC1=C2CCCC2=C(C(=C1)CCN)OC
# Converted: COC1=C2CCCCC2=C(C(=C1)CCN)OC
# Converted: COC1=C2[C@@H]3CC[C@@H](C3)C2=C(C(=C1)CCN)OC
# Converted: COC1=CC(=C(C2=CC=CC=C21)OC)CCN
# Converted: COC1=CC(=C(C=C1)OC)CCN
# Converted: COC1=CC(=C(C=C1CCN)OC)I
# Converted: COC1=CC(=C(C=C1CCN)OC)[N+](=O)[O-]
# Converted: CC(C)OC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: CCCC1=CC(=C(C=C1OC)CCN)OC
# Converted: COC1=CC(=CC(=C1OCC2CC2)OC)CCN
# Converted: COC1=CC(=C(C=C1CCN)OC)[Se]C
# Converted: COC1=CC(=C(C=C1CCN)OC)SC
# Converted: CCSC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: CC(C)SC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: CC(C)SC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: CCCSC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: COC1=CC(=C(C=C1CCN)OC)SCC2CC2
# Converted: CCCCSC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: COCCSC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: COC1=CC(=C(C=C1CCN)OC)SC2CC2
# Converted: CCC(C)SC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: COC1=CC(=C(C=C1CCN)OC)SCCF
# Converted: [2H]C([2H])([2H])OC1=C(C=C(C=C1OC)CCN)OC
# Converted: [2H]C([2H])(CN)C1=CC(=C(C(=C1)OC)OC)OC
# Converted: CC1=C(C=C(C=C1OC)CCN)OC
# Converted: CC(CC1=C(C=C(C=C1)OC)OC)N
# Converted: CC(CC1=C(C=CC(=C1)OC)OC)N
# Converted: CC(CC1=CC(=C(C=C1)OC)OC)N
# Converted: CC1=CC(=C(C=C1OC)C2CC2N)OC
# Converted: COC1=C(C=C(C=C1)C(CN)O)OC
# Converted: CC(CC1=CC(=C2C(=C1OC)OCO2)OC)N
# Converted: CC(CC1=CC2=C(C(=C1OC)OC)OCO2)N
# Converted: COC1=C(C=C(C=C1)CCN)OC
# Converted: CCCCCC1=CC(=C(C=C1OC)CC(C)N)OC
# Converted: CC(CC1=CC(=C(C=C1OC)Br)OC)N
# Converted: CCCCC1=CC(=C(C=C1OC)CC(C)N)OC
# Converted: CC(CC1=CC(=C(C=C1OC)Cl)OC)N
# Converted: CC(CC1=C(C=C(C(=C1)OC)CCF)OC)N
# Converted: CCC1=CC(=C(C=C1OC)CC(C)N)OC
# Converted: CC(CC1=CC(=C(C=C1OC)I)OC)N
# Converted: CC1=CC(=C(C=C1OC)C[C@@H](C)N)OC
# Converted: CC1=CC(=C(C(=C1)OC)C[C@@H](C)N)OC
# Converted: CC(CC1=CC(=C(C=C1OC)[N+](=O)[O-])OC)N
# Converted: CCCC1=CC(=C(C=C1OC)CC(C)N)OC
# Converted: CCOC1=C(C=C(C=C1OC)CCN)OC
# Converted: CCOC1=CC(=C(C=C1CC(C)N)OCC)OCC
# Converted: CCOC1=CC(=C(C=C1CC(C)N)OC)OCC
# Converted: CCOC1=CC(=C(C=C1CC(C)N)OCC)OC
# Converted: CCOC1=CC(=C(C=C1CC(C)N)OC)OC
# Converted: CCC(CC1=CC2=C(C=C1)OCO2)NCC
# Converted: CCCC(CC1=CC2=C(C=C1)OCO2)NCC
# Converted: CC1CC2=CC(=C(C=C2O1)CC(C)N)OC
# Converted: CC(CC1=C(C=C2CC(OC2=C1)(C)C)OC)N
# Converted: CC(CC1=CC2=C(C=C1)OCO2)N(C)O
# Converted: CC(CC1=CC(=C2CCCC2=C1OC)OC)N
# Converted: CC(CC1=CC(=C2CCCCC2=C1OC)OC)N
# Converted: CC(CC1=CC(=C2C3CCC(C3)C2=C1OC)OC)N
# Converted: CC1=C(C=C(C(=C1C)OC)CC(C)N)OC
# Converted: CC(CC1=C(C2=CC=CC=C2C(=C1)OC)OC)N
# Converted: CCSC1=C(C=C(C(=C1)OC)CCNO)OC
# Converted: CCCSC1=C(C=C(C(=C1)OC)CCNO)OC
# Converted: CCC(C)SC1=C(C=C(C(=C1)OC)CCNO)OC
# Converted: CC(CC1=CC(=C(C=C1OC)I)OC)N(C)C
# Converted: COC1=C(C(=C(C=C1)CCN)OC)OC
# Converted: CC(C)OC1=C(C=C(C=C1OC)CCN)OC
# Converted: CCOC1=CC(=C(C=C1C)OC)CC(C)N
# Converted: CCC(CC1=CC2=C(C=C1)OCO2)N
# Converted: COC1=CC(=CC2=C1OCO2)CCN
# Converted: COC1=CC(=CC(=C1OC)OC)CCN
# Converted: CC(CC1=CC=C(C=C1)OC)N
# Converted: CC1=CC2=C(C=C1CC(C)NC)OCO2
# Converted: CC(=C)COC1=C(C=C(C=C1OC)CCN)OC
# Converted: CC(CC1=CC2=C(C=C1)OCO2)N
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NCC=C
# Converted: CCCCNC(C)CC1=CC2=C(C=C1)OCO2
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NCC3=CC=CC=C3
# Converted: CC(CC1=CC2C(C=C1)OCO2)NCC3CC3
# Converted: CC(CC1=CC2=C(C=C1)OCO2)N(C)C
# Converted: CCNC(C)CC1=CC2=C(C=C1)OCO2
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NCCO
# Converted: CC(C)NC(C)CC1=CC2=C(C=C1)OCO2
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NC
# Converted: CC(CC1=CC2=C(C=C1)OCCO2)NC
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NOC
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NCCOC
# Converted: CC(C)(CC1=CC2=C(C=C1)OCO2)NC
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NO
# Converted: C1OC2=C(O1)C=C(C=C2)CCN
# Converted: CC(C)(CC1=CC2=C(C=C1)OCO2)N
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NCC#C
# Converted: CCCNC(C)CC1=CC2=C(C=C1)OCO2
# Converted: CCOC1=CC(=CC(=C1OC)OC)CCN
# Converted: CN(C)CCS.Cl
# Converted: CCOC1=C(C=C(C(=C1)CC(C)N)OC)OCC
# Converted: CCOC1=C(C=C(C(=C1)OC)CC(C)N)OC
# Converted: CCOC1=C(C=C(C=C1)CCN)OC
# Converted: CC(CC1=CC(=C(C=C1OC)OC)Br)N
# Converted: CC(CC1=CC(=C(C=C1OC)OC)SC)N
# Converted: CC(CC1=C(C=CC(=C1)OC)OC)NC
# Converted: CC(CC1=CC(=C(C=C1OC)Br)OC)NC
# Converted: CCC(CC1=CC2=C(C=C1)OCO2)NC
# Converted: CCCC(CC1=CC2=C(C=C1)OCO2)NC
# Converted: CC(CC1=CC=C(C=C1)OC)NC
# Converted: CC(CC1=CC2=C(C=C1OC)OCO2)NC
# Converted: CC(CC1=CC2=C(C(=C1)OC)OCO2)N
# Converted: CC(CC1=CC2=C(C=C1OC)OCO2)N
# Converted: CC(CC1=C(C2=C(C=C1)OCO2)OC)N
# Converted: CC(CC1=C2C(=C(C=C1)OC)OCO2)N
# Converted: CCOC1=C(C=C(C(=C1)CC(C)N)OC)OC
# Converted: CCCOC1=CC(=CC(=C1OC)OC)CCN
# Converted: CCCOC1=C(C=C(C(=C1)CC(C)N)OC)OC
# Converted: CC(CC1=CC(=C(C=C1SC)OC)OC)N
# Converted: CCCOC1=C(C=C(C=C1OC)CCN)OC
# Converted: COC1=CC(=CC(=C1OCCC2=CC=CC=C2)OC)CCN
# Converted: C1=CC=C(C=C1)CCN
# Converted: COC1=CC(=CC(=C1OCC#C)OC)CCN
# Converted: CCOC1=CC(=CC(=C1OC)OCC)CCN
# Converted: CC(CC1=CC(=C(C(=C1OC)OC)OC)OC)N
# Converted: CCOC1=C(C=C(C=C1SCC)CCN)OC
# Converted: CCOC1=CC(=CC(=C1SCC)OC)CCN
# Converted: CCOC1=C(C(=CC(=C1)CCN)SC)OCC
# Converted: CCCCSC1=C(C=C(C=C1OC)CCN)OC
# Converted: CCOC1=C(C=C(C=C1SC)CCN)OC
# Converted: CCSC1=C(C=C(C=C1OC)CCN)OC
# Converted: COC1=C(C(=C(C=C1)CCN)SC)OC
# Converted: COC1=C(C(=C(C=C1)CCN)OC)SC
# Converted: COC1=C(C=CC(=C1OC)SC)CCN
# Converted: COC1=C(C(=CC(=C1)CCN)SC)OC
# Converted: COC1=CC(=CC(=C1SC)OC)CCN
# Converted: CC(CC1=CC(=C(C(=C1)OC)OC)OC)N
# Converted: CC(CC1=CC(=C(C=C1OC)OC)OC)N
# Converted: CC(CC1=C(C(=C(C=C1)OC)OC)OC)N
# Converted: CC(CC1=C(C(=CC(=C1)OC)OC)OC)N
# Converted: CC(CC1=C(C=CC(=C1OC)OC)OC)N
# Converted: CC(CC1=C(C=C(C=C1OC)OC)OC)N
# Converted: CCSC1=CC(=CC(=C1OC)OC)CCN
# Converted: CCOC1=CC(=CC(=C1SC)OC)CCN
# Converted: CCOC1=C(C(=CC(=C1)CCN)SC)OC
# Converted: CC(CC1=C(C2=C(C=C1)OCO2)SC)N
# Converted: CC(CC1=CC2=C(C=C1OC)SCO2)N
# Converted: COC1=CC(=C(C=C1CCN)OC)OC
# Converted: CCC1=CC(=C(C=C1OC)CC(C)N)SC
# Converted: CCC1=CC(=C(C=C1SC)CC(C)N)OC
# Converted: CC1=CC(=C(C=C1OC)CC(C)N)SC
# Converted: CC1=CC(=C(C=C1SC)CC(C)N)OC
# Converted: CC1=CC(=C(C=C1S(=O)C)CC(C)N)OC.Cl
# Converted: CCCSC1=C(C=C(C=C1OC)CCN)OC
# Converted: CCOC1=CC(=CC(=C1OCC)OCC)CCN
# Converted: CCOC1=C(C(=CC(=C1)CCN)SCC)OC
# Converted: CCOC1=CC(=CC(=C1SC)OCC)CCN
# Converted: CCOC1=C(C(=CC(=C1)CCN)SCC)OCC
# Converted: CCOC1=CC(=CC(=C1SCC)OCC)CCN
# Converted: CCN(CC)C(=O)[C@H]1CN([C@@H]2CC3=CNC4=CC=CC(=C34)C2=C1)CC=C
# Converted: CCCCN(CCCC)CCC1=CNC2=CC=CC=C21
# Converted: CCN(CC)CCC1=CNC2=CC=CC=C21
# Converted: CC(C)N(CCC1=CNC2=CC=CC=C21)C(C)C
# Converted: CC(CC1=CNC2=C1C=C(C=C2)OC)N
# Converted: CN(C)CCC1=CNC2=CC=CC=C21
# Converted: CC1=C(C2=CC=CC=C2N1)CC(C)N
# Converted: CC(CC1=CNC2=CC=CC=C21)NC
# Converted: CCCN(CCC)CCC1=CNC2=CC=CC=C21
# Converted: CCN(CCC1=CNC2=CC=CC=C21)C(C)C
# Converted: CCC(CC1=CNC2=CC=CC=C21)N
# Converted: CCN1C[C@@H](C=C2[C@H]1CC3=CNC4=CC=CC2=C34)C(=O)N(CC)CC
# Converted: CC1=C2C(=C3C=CC(=CC3=N2)OC)CCN1
# Converted: CC1=NC=CC2=C1NC3=C2C=CC(=C3)OC
# Converted: CCCCN(CCCC)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CCN(CC)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CC(C)N(CCC1=CNC2=C1C(=CC=C2)O)C(C)C
# Converted: CN(C)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CN(C)CCC1=CNC2=C1C=C(C=C2)O
# Converted: CCCN(CCC)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CCN(C)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CC(C)N(C)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CCCN(C)CCC1=CNC2=C1C(=CC=C2)O
# Converted: C1CCN(C1)CCC2=CNC3=C2C(=CC=C3)O
# Converted: CC[C@H]1C[C@@H]2C[C@@H]3[C@H]1N(C2)CCC4=C3NC5=C4C=C(C=C5)OC
# Converted: CCN(CC)C(=O)[C@H]1CN([C@@H]2CC3=CNC4=CC=CC(=C34)C2=C1)C
# Converted: CCCCN(C)CCC1=CNC2=CC=CC=C21
# Converted: CC(C)N(CCC1=CNC2=C1C3=C(C=C2)OCO3)C(C)C
# Converted: CC(C)N(CCC1=CNC2=CC3=C(C=C21)OCO3)C(C)C
# Converted: CN(C)CCC1=CNC2=C1C3=C(C=C2)OCO3
# Converted: CN(C)CCC1=CNC2=CC3=C(C=C21)OCO3
# Converted: CC(C)N(C)CCC1=CNC2=CC3=C(C=C21)OCO3
# Converted: CCN(CC)CCC1=C(NC2=CC=CC=C21)C
# Converted: CC1=C(C2=CC=CC=C2N1)CCN(C)C
# Converted: CC(=O)NCCC1=CNC2=C1C=C(C=C2)OC
# Converted: CCN(CC)CCC1=CNC2=C1C=C(C=C2)OC
# Converted: CC(C)N(CCC1=CNC2=C1C=C(C=C2)OC)C(C)C
# Converted: CN(C)CCC1=CNC2=C1C=C(C=C2)OC
# Converted: CC(C)N(C)CCC1=CNC2=C1C(=CC=C2)OC
# Converted: CC(C)N(C)CCC1=CNC2=C1C=C(C=C2)OC
# Converted: CC(C)N(C)CCC1=CNC2=CC(=C(C=C21)OC)OC
# Converted: CNCCC1=CNC2=C1C=C(C=C2)OC
# Converted: COC1=CC2=C(C=C1)NC=C2CCN3CCCC3
# Converted: CC1C2=C(CCN1)C3=C(N2)C=CC(=C3)OC
# Converted: CC1=C(C2=C(N1)C=CC(=C2)OC)CCN(C)C
# Converted: CN(C)CCC1=CNC2=C1C=C(C=C2)SC
# Converted: CC(C)N(C)CCC1=CNC2=CC=CC=C21
# Converted: CC(CC1=CNC2=CC=CC=C21)N
# Converted: CCNCCC1=CNC2=CC=CC=C21
# Converted: CNCCC1=CNC2=CC=CC=C21
# Converted: CCCN1C[C@@H](C=C2[C@H]1CC3=CNC4=CC=CC2=C34)C(=O)N(CC)CC
# Converted: C1CCN(C1)CCC2=CNC3=CC=CC=C32
# Converted: C1=CC=C2C(=C1)C(=CN2)CCN
# Converted: CC1C2=C(CCN1)C3=C(N2)C=C(C=C3)OC
# Converted: CC(CC1=CNC2=C1C=C(C=C2)OC)NC

# %%
import os
import csv
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D

# Function to convert SMILES to SVG image
def smiles_to_svg(counter, smiles, output_folder):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        mol = Chem.AddHs(mol)  # Add hydrogens for a more accurate depiction
        AllChem.Compute2DCoords(mol)  # Compute 2D coordinates for the molecule
        mol = Chem.RemoveHs(mol) # delete H atoms from image
        
        # Create a blank canvas with specified dimensions
        drawer = rdMolDraw2D.MolDraw2DSVG(300, 300)
        
        # Prepare the molecule for drawing
        rdDepictor.Compute2DCoords(mol)
        
        # Draw the molecule on the canvas
        drawer.DrawMolecule(mol)
        drawer.FinishDrawing()
        
        # Get the SVG image as a string
        svg = drawer.GetDrawingText()
        
        # Generate output file path
        output_file = os.path.join(output_folder, f"{counter}. {smiles}.svg")
        
        # Save the SVG image to a file
        with open(output_file, 'w') as svg_file:
            svg_file.write(svg)
    else:
        print(f"Failed to convert SMILES: {smiles}")

# Function to convert CSV to SVG images
def convert_csv_to_svgs(input_csv, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    with open(input_csv, 'r') as csvfile:
        reader = csv.reader(csvfile)
        next(reader) # to skip the header
        counter = 1
        for row in reader:
            smiles = row[1].strip()  # SMILES strings are in the second column
            smiles_to_svg(counter, smiles, output_folder)
            print(f"Converted: {smiles}")
            counter += 1

# Specify input CSV file and output folder
input_csv = '/Users/hannah/Desktop/smiles.csv'
output_folder = '/Users/hannah/Desktop/output_folder'

# Call the function to convert CSV to SVG images
convert_csv_to_svgs(input_csv, output_folder)
# Out:
# Converted: CCC(CC1=CC(=C(C(=C1)OC)OC)OC)N
# Converted: COC1=CC(=CC(=C1OCC=C)OC)CCN
# Converted: CC(CC1=CC(=C(C=C1OC)SC)OC)N
# Converted: CCSC1=C(C=C(C(=C1)OC)CC(C)N)OC
# Converted: CC(C)SC1=C(C=C(C(=C1)OC)CC(C)N)OC
# Converted: CC(CC1=CC(=C(C=C1OC)SC2=CC=CC=C2)OC)N
# Converted: CCCSC1=C(C=C(C(=C1)OC)CC(C)N)OC
# Converted: CCC(CC1=C(C=C(C(=C1)OC)C)OC)N
# Converted: CCOC1=CC(=CC(=C1OCC)OC)CCN
# Converted: CCCCOC1=C(C=C(C=C1OC)CCN)OC
# Converted: CC1=CC(=C(C=C1OC)CC(C)NC)OC
# Converted: CC1=CC(=C(C=C1SC)CC(C)N)SC
# Converted: COC1=CC(=C(C=C1C(CN)OC)OC)Br
# Converted: CC1=CC(=C(C=C1OC)C(CN)OC)OC
# Converted: COC(CN)C1=CC2=C(C=C1)OCO2
# Converted: CC1=CC(=C(C=C1OC)C(CN)O)OC
# Converted: COC1=CC(=CC(=C1OC)OC)C(CN)OC
# Converted: CC(CC1=CC(=C(C(=C1)OC)Br)OC)N
# Converted: CC(CC1=CC2=C(C=C1Br)OCO2)N
# Converted: COC1=CC(=C(C=C1CCN)OC)Br
# Converted: CC(CC1=CC(=C(C(=C1)OC)OCC2=CC=CC=C2)OC)N
# Converted: COC1=CC(=C(C=C1CCN)OC)Cl
# Converted: CC1=CC(=C(C=C1OC)CCN)OC
# Converted: CCC1=CC(=C(C=C1OC)CCN)OC
# Converted: CCOC1=C(C=C(C=C1OC)CC(C)N)OC
# Converted: COC1=CC(=C(C=C1CCN)OC)F
# Converted: CC1=C(C=C(C(=C1C)OC)CCN)OC
# Converted: COC1=C2CCCC2=C(C(=C1)CCN)OC
# Converted: COC1=C2CCCCC2=C(C(=C1)CCN)OC
# Converted: COC1=C2[C@@H]3CC[C@@H](C3)C2=C(C(=C1)CCN)OC
# Converted: COC1=CC(=C(C2=CC=CC=C21)OC)CCN
# Converted: COC1=CC(=C(C=C1)OC)CCN
# Converted: COC1=CC(=C(C=C1CCN)OC)I
# Converted: COC1=CC(=C(C=C1CCN)OC)[N+](=O)[O-]
# Converted: CC(C)OC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: CCCC1=CC(=C(C=C1OC)CCN)OC
# Converted: COC1=CC(=CC(=C1OCC2CC2)OC)CCN
# Converted: COC1=CC(=C(C=C1CCN)OC)[Se]C
# Converted: COC1=CC(=C(C=C1CCN)OC)SC
# Converted: CCSC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: CC(C)SC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: CC(C)SC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: CCCSC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: COC1=CC(=C(C=C1CCN)OC)SCC2CC2
# Converted: CCCCSC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: COCCSC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: COC1=CC(=C(C=C1CCN)OC)SC2CC2
# Converted: CCC(C)SC1=C(C=C(C(=C1)OC)CCN)OC
# Converted: COC1=CC(=C(C=C1CCN)OC)SCCF
# Converted: [2H]C([2H])([2H])OC1=C(C=C(C=C1OC)CCN)OC
# Converted: [2H]C([2H])(CN)C1=CC(=C(C(=C1)OC)OC)OC
# Converted: CC1=C(C=C(C=C1OC)CCN)OC
# Converted: CC(CC1=C(C=C(C=C1)OC)OC)N
# Converted: CC(CC1=C(C=CC(=C1)OC)OC)N
# Converted: CC(CC1=CC(=C(C=C1)OC)OC)N
# Converted: CC1=CC(=C(C=C1OC)C2CC2N)OC
# Converted: COC1=C(C=C(C=C1)C(CN)O)OC
# Converted: CC(CC1=CC(=C2C(=C1OC)OCO2)OC)N
# Converted: CC(CC1=CC2=C(C(=C1OC)OC)OCO2)N
# Converted: COC1=C(C=C(C=C1)CCN)OC
# Converted: CCCCCC1=CC(=C(C=C1OC)CC(C)N)OC
# Converted: CC(CC1=CC(=C(C=C1OC)Br)OC)N
# Converted: CCCCC1=CC(=C(C=C1OC)CC(C)N)OC
# Converted: CC(CC1=CC(=C(C=C1OC)Cl)OC)N
# Converted: CC(CC1=C(C=C(C(=C1)OC)CCF)OC)N
# Converted: CCC1=CC(=C(C=C1OC)CC(C)N)OC
# Converted: CC(CC1=CC(=C(C=C1OC)I)OC)N
# Converted: CC1=CC(=C(C=C1OC)C[C@@H](C)N)OC
# Converted: CC1=CC(=C(C(=C1)OC)C[C@@H](C)N)OC
# Converted: CC(CC1=CC(=C(C=C1OC)[N+](=O)[O-])OC)N
# Converted: CCCC1=CC(=C(C=C1OC)CC(C)N)OC
# Converted: CCOC1=C(C=C(C=C1OC)CCN)OC
# Converted: CCOC1=CC(=C(C=C1CC(C)N)OCC)OCC
# Converted: CCOC1=CC(=C(C=C1CC(C)N)OC)OCC
# Converted: CCOC1=CC(=C(C=C1CC(C)N)OCC)OC
# Converted: CCOC1=CC(=C(C=C1CC(C)N)OC)OC
# Converted: CCC(CC1=CC2=C(C=C1)OCO2)NCC
# Converted: CCCC(CC1=CC2=C(C=C1)OCO2)NCC
# Converted: CC1CC2=CC(=C(C=C2O1)CC(C)N)OC
# Converted: CC(CC1=C(C=C2CC(OC2=C1)(C)C)OC)N
# Converted: CC(CC1=CC2=C(C=C1)OCO2)N(C)O
# Converted: CC(CC1=CC(=C2CCCC2=C1OC)OC)N
# Converted: CC(CC1=CC(=C2CCCCC2=C1OC)OC)N
# Converted: CC(CC1=CC(=C2C3CCC(C3)C2=C1OC)OC)N
# Converted: CC1=C(C=C(C(=C1C)OC)CC(C)N)OC
# Converted: CC(CC1=C(C2=CC=CC=C2C(=C1)OC)OC)N
# Converted: CCSC1=C(C=C(C(=C1)OC)CCNO)OC
# Converted: CCCSC1=C(C=C(C(=C1)OC)CCNO)OC
# Converted: CCC(C)SC1=C(C=C(C(=C1)OC)CCNO)OC
# Converted: CC(CC1=CC(=C(C=C1OC)I)OC)N(C)C
# Converted: COC1=C(C(=C(C=C1)CCN)OC)OC
# Converted: CC(C)OC1=C(C=C(C=C1OC)CCN)OC
# Converted: CCOC1=CC(=C(C=C1C)OC)CC(C)N
# Converted: CCC(CC1=CC2=C(C=C1)OCO2)N
# Converted: COC1=CC(=CC2=C1OCO2)CCN
# Converted: COC1=CC(=CC(=C1OC)OC)CCN
# Converted: CC(CC1=CC=C(C=C1)OC)N
# Converted: CC1=CC2=C(C=C1CC(C)NC)OCO2
# Converted: CC(=C)COC1=C(C=C(C=C1OC)CCN)OC
# Converted: CC(CC1=CC2=C(C=C1)OCO2)N
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NCC=C
# Converted: CCCCNC(C)CC1=CC2=C(C=C1)OCO2
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NCC3=CC=CC=C3
# Converted: CC(CC1=CC2C(C=C1)OCO2)NCC3CC3
# Converted: CC(CC1=CC2=C(C=C1)OCO2)N(C)C
# Converted: CCNC(C)CC1=CC2=C(C=C1)OCO2
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NCCO
# Converted: CC(C)NC(C)CC1=CC2=C(C=C1)OCO2
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NC
# Converted: CC(CC1=CC2=C(C=C1)OCCO2)NC
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NOC
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NCCOC
# Converted: CC(C)(CC1=CC2=C(C=C1)OCO2)NC
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NO
# Converted: C1OC2=C(O1)C=C(C=C2)CCN
# Converted: CC(C)(CC1=CC2=C(C=C1)OCO2)N
# Converted: CC(CC1=CC2=C(C=C1)OCO2)NCC#C
# Converted: CCCNC(C)CC1=CC2=C(C=C1)OCO2
# Converted: CCOC1=CC(=CC(=C1OC)OC)CCN
# Converted: CN(C)CCS.Cl
# Converted: CCOC1=C(C=C(C(=C1)CC(C)N)OC)OCC
# Converted: CCOC1=C(C=C(C(=C1)OC)CC(C)N)OC
# Converted: CCOC1=C(C=C(C=C1)CCN)OC
# Converted: CC(CC1=CC(=C(C=C1OC)OC)Br)N
# Converted: CC(CC1=CC(=C(C=C1OC)OC)SC)N
# Converted: CC(CC1=C(C=CC(=C1)OC)OC)NC
# Converted: CC(CC1=CC(=C(C=C1OC)Br)OC)NC
# Converted: CCC(CC1=CC2=C(C=C1)OCO2)NC
# Converted: CCCC(CC1=CC2=C(C=C1)OCO2)NC
# Converted: CC(CC1=CC=C(C=C1)OC)NC
# Converted: CC(CC1=CC2=C(C=C1OC)OCO2)NC
# Converted: CC(CC1=CC2=C(C(=C1)OC)OCO2)N
# Converted: CC(CC1=CC2=C(C=C1OC)OCO2)N
# Converted: CC(CC1=C(C2=C(C=C1)OCO2)OC)N
# Converted: CC(CC1=C2C(=C(C=C1)OC)OCO2)N
# Converted: CCOC1=C(C=C(C(=C1)CC(C)N)OC)OC
# Converted: CCCOC1=CC(=CC(=C1OC)OC)CCN
# Converted: CCCOC1=C(C=C(C(=C1)CC(C)N)OC)OC
# Converted: CC(CC1=CC(=C(C=C1SC)OC)OC)N
# Converted: CCCOC1=C(C=C(C=C1OC)CCN)OC
# Converted: COC1=CC(=CC(=C1OCCC2=CC=CC=C2)OC)CCN
# Converted: C1=CC=C(C=C1)CCN
# Converted: COC1=CC(=CC(=C1OCC#C)OC)CCN
# Converted: CCOC1=CC(=CC(=C1OC)OCC)CCN
# Converted: CC(CC1=CC(=C(C(=C1OC)OC)OC)OC)N
# Converted: CCOC1=C(C=C(C=C1SCC)CCN)OC
# Converted: CCOC1=CC(=CC(=C1SCC)OC)CCN
# Converted: CCOC1=C(C(=CC(=C1)CCN)SC)OCC
# Converted: CCCCSC1=C(C=C(C=C1OC)CCN)OC
# Converted: CCOC1=C(C=C(C=C1SC)CCN)OC
# Converted: CCSC1=C(C=C(C=C1OC)CCN)OC
# Converted: COC1=C(C(=C(C=C1)CCN)SC)OC
# Converted: COC1=C(C(=C(C=C1)CCN)OC)SC
# Converted: COC1=C(C=CC(=C1OC)SC)CCN
# Converted: COC1=C(C(=CC(=C1)CCN)SC)OC
# Converted: COC1=CC(=CC(=C1SC)OC)CCN
# Converted: CC(CC1=CC(=C(C(=C1)OC)OC)OC)N
# Converted: CC(CC1=CC(=C(C=C1OC)OC)OC)N
# Converted: CC(CC1=C(C(=C(C=C1)OC)OC)OC)N
# Converted: CC(CC1=C(C(=CC(=C1)OC)OC)OC)N
# Converted: CC(CC1=C(C=CC(=C1OC)OC)OC)N
# Converted: CC(CC1=C(C=C(C=C1OC)OC)OC)N
# Converted: CCSC1=CC(=CC(=C1OC)OC)CCN
# Converted: CCOC1=CC(=CC(=C1SC)OC)CCN
# Converted: CCOC1=C(C(=CC(=C1)CCN)SC)OC
# Converted: CC(CC1=C(C2=C(C=C1)OCO2)SC)N
# Converted: CC(CC1=CC2=C(C=C1OC)SCO2)N
# Converted: COC1=CC(=C(C=C1CCN)OC)OC
# Converted: CCC1=CC(=C(C=C1OC)CC(C)N)SC
# Converted: CCC1=CC(=C(C=C1SC)CC(C)N)OC
# Converted: CC1=CC(=C(C=C1OC)CC(C)N)SC
# Converted: CC1=CC(=C(C=C1SC)CC(C)N)OC
# Converted: CC1=CC(=C(C=C1S(=O)C)CC(C)N)OC.Cl
# Converted: CCCSC1=C(C=C(C=C1OC)CCN)OC
# Converted: CCOC1=CC(=CC(=C1OCC)OCC)CCN
# Converted: CCOC1=C(C(=CC(=C1)CCN)SCC)OC
# Converted: CCOC1=CC(=CC(=C1SC)OCC)CCN
# Converted: CCOC1=C(C(=CC(=C1)CCN)SCC)OCC
# Converted: CCOC1=CC(=CC(=C1SCC)OCC)CCN
# Converted: CCN(CC)C(=O)[C@H]1CN([C@@H]2CC3=CNC4=CC=CC(=C34)C2=C1)CC=C
# Converted: CCCCN(CCCC)CCC1=CNC2=CC=CC=C21
# Converted: CCN(CC)CCC1=CNC2=CC=CC=C21
# Converted: CC(C)N(CCC1=CNC2=CC=CC=C21)C(C)C
# Converted: CC(CC1=CNC2=C1C=C(C=C2)OC)N
# Converted: CN(C)CCC1=CNC2=CC=CC=C21
# Converted: CC1=C(C2=CC=CC=C2N1)CC(C)N
# Converted: CC(CC1=CNC2=CC=CC=C21)NC
# Converted: CCCN(CCC)CCC1=CNC2=CC=CC=C21
# Converted: CCN(CCC1=CNC2=CC=CC=C21)C(C)C
# Converted: CCC(CC1=CNC2=CC=CC=C21)N
# Converted: CCN1C[C@@H](C=C2[C@H]1CC3=CNC4=CC=CC2=C34)C(=O)N(CC)CC
# Converted: CC1=C2C(=C3C=CC(=CC3=N2)OC)CCN1
# Converted: CC1=NC=CC2=C1NC3=C2C=CC(=C3)OC
# Converted: CCCCN(CCCC)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CCN(CC)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CC(C)N(CCC1=CNC2=C1C(=CC=C2)O)C(C)C
# Converted: CN(C)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CN(C)CCC1=CNC2=C1C=C(C=C2)O
# Converted: CCCN(CCC)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CCN(C)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CC(C)N(C)CCC1=CNC2=C1C(=CC=C2)O
# Converted: CCCN(C)CCC1=CNC2=C1C(=CC=C2)O
# Converted: C1CCN(C1)CCC2=CNC3=C2C(=CC=C3)O
# Converted: CC[C@H]1C[C@@H]2C[C@@H]3[C@H]1N(C2)CCC4=C3NC5=C4C=C(C=C5)OC
# Converted: CCN(CC)C(=O)[C@H]1CN([C@@H]2CC3=CNC4=CC=CC(=C34)C2=C1)C
# Converted: CCCCN(C)CCC1=CNC2=CC=CC=C21
# Converted: CC(C)N(CCC1=CNC2=C1C3=C(C=C2)OCO3)C(C)C
# Converted: CC(C)N(CCC1=CNC2=CC3=C(C=C21)OCO3)C(C)C
# Converted: CN(C)CCC1=CNC2=C1C3=C(C=C2)OCO3
# Converted: CN(C)CCC1=CNC2=CC3=C(C=C21)OCO3
# Converted: CC(C)N(C)CCC1=CNC2=CC3=C(C=C21)OCO3
# Converted: CCN(CC)CCC1=C(NC2=CC=CC=C21)C
# Converted: CC1=C(C2=CC=CC=C2N1)CCN(C)C
# Converted: CC(=O)NCCC1=CNC2=C1C=C(C=C2)OC
# Converted: CCN(CC)CCC1=CNC2=C1C=C(C=C2)OC
# Converted: CC(C)N(CCC1=CNC2=C1C=C(C=C2)OC)C(C)C
# Converted: CN(C)CCC1=CNC2=C1C=C(C=C2)OC
# Converted: CC(C)N(C)CCC1=CNC2=C1C(=CC=C2)OC
# Converted: CC(C)N(C)CCC1=CNC2=C1C=C(C=C2)OC
# Converted: CC(C)N(C)CCC1=CNC2=CC(=C(C=C21)OC)OC
# Converted: CNCCC1=CNC2=C1C=C(C=C2)OC
# Converted: COC1=CC2=C(C=C1)NC=C2CCN3CCCC3
# Converted: CC1C2=C(CCN1)C3=C(N2)C=CC(=C3)OC
# Converted: CC1=C(C2=C(N1)C=CC(=C2)OC)CCN(C)C
# Converted: CN(C)CCC1=CNC2=C1C=C(C=C2)SC
# Converted: CC(C)N(C)CCC1=CNC2=CC=CC=C21
# Converted: CC(CC1=CNC2=CC=CC=C21)N
# Converted: CCNCCC1=CNC2=CC=CC=C21
# Converted: CNCCC1=CNC2=CC=CC=C21
# Converted: CCCN1C[C@@H](C=C2[C@H]1CC3=CNC4=CC=CC2=C34)C(=O)N(CC)CC
# Converted: C1CCN(C1)CCC2=CNC3=CC=CC=C32
# Converted: C1=CC=C2C(=C1)C(=CN2)CCN
# Converted: CC1C2=C(CCN1)C3=C(N2)C=C(C=C3)OC
# Converted: CC(CC1=CNC2=C1C=C(C=C2)OC)NC
