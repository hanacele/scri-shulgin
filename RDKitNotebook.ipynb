# %%
pip install rdkit-pypi
# Out:
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp39-cp39-macosx_10_9_x86_64.whl (24.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 26.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /Users/hannah/anaconda3/envs/pikachu/lib/python3.9/site-packages (from rdkit-pypi) (1.26.1)
# Requirement already satisfied: Pillow in /Users/hannah/anaconda3/envs/pikachu/lib/python3.9/site-packages (from rdkit-pypi) (10.1.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from rdkit import Chem

# %%
from rdkit.Chem import Draw

# %%
smiles = 'C1=CC(=C(C=C1C2=C(C(=O)C3=C(C=C(C=C3O2)O)O)O)O)O'

# %%
m = Chem.MolFromSmiles(smiles)

# %%
Draw.MolToImage(m)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
smiles = 'C1(=C2C(=C(C=C1CC(C)N([H])[H])OC)C3CCC2C3)OC'
m = Chem.MolFromSmiles(smiles)
Draw.MolToImage(m)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
smiles = 'CC(CC1=CC(=C2C3CCC(C3)C2=C1OC)OC)N  '
m = Chem.MolFromSmiles(smiles)
Draw.MolToImage(m)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
